# %% [markdown]
# controling our system via python-File Handling

# %%
#reading a file
import os
l=open("C:/Users/Administrator/Desktop/myfile.txt","r")#absolute path
print(l.read())
l.close()
# Out:
# hello

# %%
#creating a new file and writing to it
import os 
os.getenv("C:/Users/Administrator")#home directory(commandline default path)
l=open("myfile1.txt","w")#relative path
l.write("New file created\n")
l.write("another line added")
l.close()

# %%
#reading from the created file
import os 
os.getenv("C:/Users/Administrator")#still its jupyter i am not adding at each cell
l=open("myfile1.txt","r")
l.read()
# Out:
# 'New file created\nanother line added'

# %%
a="this is my college"
a[5:10]#slicing same we use pointer in file handling
#in string the pointer will go back to 0 after slicing but in files it stick to the last position
# Out:
# 'is my'

# %%
l=open("myfile1.txt","r")
l.read(4) # read upto 4 chars(bytes)
# Out:
# 'New '

# %%
l.tell() # it tells the cursors position
# Out:
# 4

# %%
l=open("myfile1.txt","r")
l.seek(4)# helps to move the cursor to our desired position
l.read()
# Out:
# 'file created\nanother line added'

# %%
l.seek(9)
l.read()
# Out:
# 'created\nanother line added'

# %%
l=open("myfile1.txt","r")
l.readline()
# Out:
# 'New file created\n'

# %%
l.readline()
# Out:
# 'another line added'

# %%
l=open("myfile1.txt","r")
l.readlines()
l.close()
# Out:
# ['New file created\n', 'another line added']

# %%
import os
os.chdir("C:/Users/Administrator/Desktop")
os.rename("my.txt","file1.txt")#renaming file name

# %%
import os
os.getcwd()#to know the current working directory
# Out:
# 'C:\\Users\\Administrator'

# %%
os.chdir("C:/Users/Administrator/Desktop") #to change the directory

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\Desktop'

# %%
os.listdir(os.getcwdb()) #to list all files in specified directory
# Out:
# [b'assignment.txt',
#  b'desktop.ini',
#  b'Microsoft Edge.lnk',
#  b'MongoDB Compass.lnk',
#  b'myfile.txt',
#  b'Readme - Shortcut.lnk']

# %%
os.mkdir("New directory") #this directory is created in current working directory which is desktop(C:/Users/Administrator/Desktop/New directory)

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\Desktop'

# %%
os.listdir(os.getcwd())
# Out:
# ['assignment.txt',
#  'desktop.ini',
#  'Microsoft Edge.lnk',
#  'MongoDB Compass.lnk',
#  'my.txt',
#  'myfile.txt',
#  'New directory',
#  'Readme - Shortcut.lnk']

# %%
import os
os.rmdir("C:/Users/Administrator/Desktop/New directory")#to delete only empty directories

# %% [markdown]
# Modules

# %%
import math
math.sqrt(25)
# Out:
# 5.0

# %%
import math as m #alias for importing module
m.sqrt(25)
# Out:
# 5.0

# %%
import datetime as dt
dt.datetime.now()
# Out:
# datetime.datetime(2026, 2, 20, 11, 33, 10, 336275)

# %%
from datetime import datetime #importing particular function from a module
datetime.now()
# Out:
# datetime.datetime(2026, 2, 20, 11, 33, 42, 121438)

# %%
from math import * #* means importing all
import math
print(sqrt(25)) #still we used * so directly sqrt()
print(math.pi)
# Out:
# 5.0
# 3.141592653589793
