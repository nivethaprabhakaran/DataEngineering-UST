# %%
import os
os.chdir("C:/Users/Administrator/Desktop")
os.mkdir("My directory")

# %%
l=open("C:/Users/Administrator/Desktop/My directory/My file","w")
l.write("This is my file\n")
l.write("This file is created by me")
l.close()

# %%
l=open("C:/Users/Administrator/Desktop/My directory/My file","r")
l.read()
l.close()

# %% [markdown]
# Trying to remove non empty directory with rmdir gives error

# %%
import os
os.rmdir("C:/Users/Administrator/Desktop/My directory")#using rmdir can't delete non empty directory
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[14], line 2
#       1 import os
# ----> 2 os.rmdir("C:/Users/Administrator/Desktop/My directory")
#
# OSError: [WinError 145] The directory is not empty: 'C:/Users/Administrator/Desktop/My directory'

# %%
import os
os.chdir("C:/Users/Administrator/Desktop/My directory")
l=open("My file.txt","w")
l.write("\nAnother line")
l.close()

# %%
import shutil
import os
os.chdir("C:/Users/Administrator/Desktop")
shutil.rmtree("C:/Users/Administrator/Desktop/My directory")

# %%
#trying to check whether its successfully deleted or not
import os
os.path.exists("C:/Users/Administrator/Desktop/My directory")
# Out:
# False
